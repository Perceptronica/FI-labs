# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
plt.grid()
rectangle = plt.Rectangle((5, -5), 10, -10, fc="white", ec="red")
plt.gca().add_patch(rectangle)
plt.axis([-20, 20, -20, 20])
#plt.subplots.set_aspect('equal', 'box')
#plt.axis('scaled')
plt.show()
